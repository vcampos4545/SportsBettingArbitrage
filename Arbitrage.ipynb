# %% [markdown]
# # Statistical Arbitrage for Sports Betting

# %% [markdown]
# Using: Live Sports Odds API
# Documentation Link: https://the-odds-api.com/

# %% [markdown]
# This program will look for statistical arbitrage opportunities in the upcoming eight games across all sports.

# %% [markdown]
# ### Importing Dependencies and Acquiring API Key

# %%
# !pip install XlsxWriter
# Out:
# Requirement already satisfied: XlsxWriter in /Users/vaughncampos/.pyenv/versions/3.7.3/lib/python3.7/site-packages (3.1.2)

# %%
import requests
import xlsxwriter
import pandas as pd
import numpy as np
import openpyxl
from openpyxl import Workbook, load_workbook
from openpyxl.styles import Border, Side, Font, Alignment, PatternFill, numbers

# f = open('API_KEY.txt', 'r')
# API_KEY = f.read()
# f.close()

# %% [markdown]
# ### Defining Constants and Making API Call
# - ``BET_SIZE`` is the monetary amount in USD that you are willing to make for each bet. For example, if you define ``BET_SIZE`` as 100, you are telling the program that you want to bet a total of 100 dollars USD for each arbitrage opportunity that the program finds

# %%
SPORT = 'upcoming' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'h2h' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'decimal' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

BET_SIZE = 100

odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': '44cc53b431d4792178de3ba7d9565fa3',
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
).json()

# %%
# odds_response
odds_response
# Out:
# [{'id': '5239fca911e909eec9acb55a6e61ee78',
#   'sport_key': 'cricket_t20_blast',
#   'sport_title': 'T20 Blast',
#   'commence_time': '2023-06-23T17:30:00Z',
#   'home_team': 'Somerset',
#   'away_team': 'Gloucestershire',
#   'bookmakers': [{'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2023-06-23T19:01:44Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:44Z',
#       'outcomes': [{'name': 'Gloucestershire', 'price': 3.0},
#        {'name': 'Somerset', 'price': 1.36}]}]}]},
#  {'id': '57232cd50f2c69f0beef61485450fd87',
#   'sport_key': 'soccer_league_of_ireland',
#   'sport_title': 'League of Ireland',
#   'commence_time': '2023-06-23T18:44:42Z',
#   'home_team': 'Drogheda United',
#   'away_team': 'Dundalk',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2023-06-23T19:01:41Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:41Z',
#       'outcomes': [{'name': 'Drogheda United', 'price': 1.53},
#        {'name': 'Dundalk', 'price': 6.0},
#        {'name': 'Draw', 'price': 4.1}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2023-06-23T19:01:44Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:44Z',
#       'outcomes': [{'name': 'Drogheda United', 'price': 1.56},
#        {'name': 'Dundalk', 'price': 5.5},
#        {'name': 'Draw', 'price': 3.95}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2023-06-23T19:01:45Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:45Z',
#       'outcomes': [{'name': 'Drogheda United', 'price': 1.55},
#        {'name': 'Dundalk', 'price': 5.0},
#        {'name': 'Draw', 'price': 3.75}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2023-06-23T19:01:29Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:29Z',
#       'outcomes': [{'name': 'Drogheda United', 'price': 1.54},
#        {'name': 'Dundalk', 'price': 5.2},
#        {'name': 'Draw', 'price': 3.7}]}]}]},
#  {'id': 'd179517f810d434ed4759fb9e9d66816',
#   'sport_key': 'soccer_league_of_ireland',
#   'sport_title': 'League of Ireland',
#   'commence_time': '2023-06-23T18:44:57Z',
#   'home_team': 'St Patricks Athletic',
#   'away_team': 'Shelbourne Dublin',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2023-06-23T19:01:41Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:41Z',
#       'outcomes': [{'name': 'Shelbourne Dublin', 'price': 3.3},
#        {'name': 'St Patricks Athletic', 'price': 2.25},
#        {'name': 'Draw', 'price': 3.15}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2023-06-23T19:01:44Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:44Z',
#       'outcomes': [{'name': 'Shelbourne Dublin', 'price': 3.45},
#        {'name': 'St Patricks Athletic', 'price': 2.3},
#        {'name': 'Draw', 'price': 2.85}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2023-06-23T19:01:45Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:45Z',
#       'outcomes': [{'name': 'Shelbourne Dublin', 'price': 3.2},
#        {'name': 'St Patricks Athletic', 'price': 2.25},
#        {'name': 'Draw', 'price': 2.88}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2023-06-23T19:01:29Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:29Z',
#       'outcomes': [{'name': 'Shelbourne Dublin', 'price': 3.2},
#        {'name': 'St Patricks Athletic', 'price': 2.35},
#        {'name': 'Draw', 'price': 2.7}]}]}]},
#  {'id': 'de2279f7d9dbb99e79a9e43c516d014d',
#   'sport_key': 'soccer_league_of_ireland',
#   'sport_title': 'League of Ireland',
#   'commence_time': '2023-06-23T18:46:04Z',
#   'home_team': 'Derry City',
#   'away_team': 'Cork City',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2023-06-23T19:01:41Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:41Z',
#       'outcomes': [{'name': 'Cork City', 'price': 6.0},
#        {'name': 'Derry City', 'price': 1.57},
#        {'name': 'Draw', 'price': 3.75}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2023-06-23T19:01:44Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:44Z',
#       'outcomes': [{'name': 'Cork City', 'price': 5.6},
#        {'name': 'Derry City', 'price': 1.56},
#        {'name': 'Draw', 'price': 3.85}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2023-06-23T19:01:45Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:45Z',
#       'outcomes': [{'name': 'Cork City', 'price': 6.0},
#        {'name': 'Derry City', 'price': 1.53},
#        {'name': 'Draw', 'price': 3.45}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2023-06-23T19:01:29Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:29Z',
#       'outcomes': [{'name': 'Cork City', 'price': 5.9},
#        {'name': 'Derry City', 'price': 1.59},
#        {'name': 'Draw', 'price': 3.25}]}]}]},
#  {'id': '10697160a162e0490cb3d323de4a8cd4',
#   'sport_key': 'soccer_league_of_ireland',
#   'sport_title': 'League of Ireland',
#   'commence_time': '2023-06-23T18:46:41Z',
#   'home_team': 'Bohemians',
#   'away_team': 'Shamrock Rovers',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2023-06-23T19:01:41Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:41Z',
#       'outcomes': [{'name': 'Bohemians', 'price': 3.25},
#        {'name': 'Shamrock Rovers', 'price': 2.35},
#        {'name': 'Draw', 'price': 3.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2023-06-23T19:01:44Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:44Z',
#       'outcomes': [{'name': 'Bohemians', 'price': 3.3},
#        {'name': 'Shamrock Rovers', 'price': 2.32},
#        {'name': 'Draw', 'price': 2.9}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2023-06-23T19:01:45Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:45Z',
#       'outcomes': [{'name': 'Bohemians', 'price': 3.3},
#        {'name': 'Shamrock Rovers', 'price': 2.2},
#        {'name': 'Draw', 'price': 2.9}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2023-06-23T19:01:29Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:29Z',
#       'outcomes': [{'name': 'Bohemians', 'price': 3.15},
#        {'name': 'Shamrock Rovers', 'price': 2.29},
#        {'name': 'Draw', 'price': 2.8}]}]}]},
#  {'id': 'fdde87cae3333b477f68f1e269b3d0ab',
#   'sport_key': 'soccer_league_of_ireland',
#   'sport_title': 'League of Ireland',
#   'commence_time': '2023-06-23T18:46:56Z',
#   'home_team': 'UC Dublin',
#   'away_team': 'Sligo Rovers',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2023-06-23T19:01:41Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:41Z',
#       'outcomes': [{'name': 'Sligo Rovers', 'price': 1.48},
#        {'name': 'UC Dublin', 'price': 7.0},
#        {'name': 'Draw', 'price': 4.1}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2023-06-23T19:01:44Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:44Z',
#       'outcomes': [{'name': 'Sligo Rovers', 'price': 1.49},
#        {'name': 'UC Dublin', 'price': 6.5},
#        {'name': 'Draw', 'price': 3.95}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2023-06-23T19:01:45Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:45Z',
#       'outcomes': [{'name': 'Sligo Rovers', 'price': 1.44},
#        {'name': 'UC Dublin', 'price': 6.0},
#        {'name': 'Draw', 'price': 3.8}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2023-06-23T19:01:29Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:29Z',
#       'outcomes': [{'name': 'Sligo Rovers', 'price': 1.49},
#        {'name': 'UC Dublin', 'price': 6.25},
#        {'name': 'Draw', 'price': 3.55}]}]}]},
#  {'id': '0ae58f6f772952179054ced302e2277c',
#   'sport_key': 'soccer_brazil_serie_b',
#   'sport_title': 'Brazil Série B',
#   'commence_time': '2023-06-23T22:00:00Z',
#   'home_team': 'Atletico Goianiense',
#   'away_team': 'Ponte Preta',
#   'bookmakers': [{'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2023-06-23T19:01:15Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:15Z',
#       'outcomes': [{'name': 'Atletico Goianiense', 'price': 1.62},
#        {'name': 'Ponte Preta', 'price': 5.0},
#        {'name': 'Draw', 'price': 3.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2023-06-23T19:01:02Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:02Z',
#       'outcomes': [{'name': 'Atletico Goianiense', 'price': 1.6},
#        {'name': 'Ponte Preta', 'price': 4.75},
#        {'name': 'Draw', 'price': 3.3}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2023-06-23T19:01:39Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:39Z',
#       'outcomes': [{'name': 'Atletico Goianiense', 'price': 1.65},
#        {'name': 'Ponte Preta', 'price': 5.0},
#        {'name': 'Draw', 'price': 3.7}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2023-06-23T19:01:29Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:29Z',
#       'outcomes': [{'name': 'Atletico Goianiense', 'price': 1.67},
#        {'name': 'Ponte Preta', 'price': 5.5},
#        {'name': 'Draw', 'price': 3.7}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2023-06-23T19:00:55Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:55Z',
#       'outcomes': [{'name': 'Atletico Goianiense', 'price': 1.62},
#        {'name': 'Ponte Preta', 'price': 5.6},
#        {'name': 'Draw', 'price': 3.6}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2023-06-23T19:01:31Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:31Z',
#       'outcomes': [{'name': 'Atletico Goianiense', 'price': 1.71},
#        {'name': 'Ponte Preta', 'price': 5.0},
#        {'name': 'Draw', 'price': 3.65}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2023-06-23T19:01:22Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:22Z',
#       'outcomes': [{'name': 'Atletico Goianiense', 'price': 1.7},
#        {'name': 'Ponte Preta', 'price': 4.5},
#        {'name': 'Draw', 'price': 3.4}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2023-06-23T19:00:42Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:42Z',
#       'outcomes': [{'name': 'Atletico Goianiense', 'price': 1.7},
#        {'name': 'Ponte Preta', 'price': 4.5},
#        {'name': 'Draw', 'price': 3.4}]}]}]},
#  {'id': '7d3508812228e803c77bd4b07feedd72',
#   'sport_key': 'soccer_argentina_primera_division',
#   'sport_title': 'Primera División - Argentina',
#   'commence_time': '2023-06-23T22:00:00Z',
#   'home_team': 'Atlético Huracán',
#   'away_team': 'Newells Old Boys',
#   'bookmakers': [{'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2023-06-23T19:01:09Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:09Z',
#       'outcomes': [{'name': 'Atlético Huracán', 'price': 2.75},
#        {'name': 'Newells Old Boys', 'price': 2.85},
#        {'name': 'Draw', 'price': 2.65}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2023-06-23T19:01:21Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:21Z',
#       'outcomes': [{'name': 'Atlético Huracán', 'price': 2.6},
#        {'name': 'Newells Old Boys', 'price': 2.7},
#        {'name': 'Draw', 'price': 2.6}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2023-06-23T19:01:20Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:20Z',
#       'outcomes': [{'name': 'Atlético Huracán', 'price': 2.85},
#        {'name': 'Newells Old Boys', 'price': 2.9},
#        {'name': 'Draw', 'price': 2.75}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2023-06-23T19:01:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:48Z',
#       'outcomes': [{'name': 'Atlético Huracán', 'price': 2.9},
#        {'name': 'Newells Old Boys', 'price': 2.95},
#        {'name': 'Draw', 'price': 2.75}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2023-06-23T19:00:59Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:59Z',
#       'outcomes': [{'name': 'Atlético Huracán', 'price': 2.85},
#        {'name': 'Newells Old Boys', 'price': 2.9},
#        {'name': 'Draw', 'price': 2.65}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2023-06-23T19:02:02Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:02:02Z',
#       'outcomes': [{'name': 'Atlético Huracán', 'price': 2.9},
#        {'name': 'Newells Old Boys', 'price': 2.9},
#        {'name': 'Draw', 'price': 2.8}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2023-06-23T19:01:59Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:59Z',
#       'outcomes': [{'name': 'Atlético Huracán', 'price': 2.85},
#        {'name': 'Newells Old Boys', 'price': 2.85},
#        {'name': 'Draw', 'price': 2.75}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2023-06-23T19:00:55Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:55Z',
#       'outcomes': [{'name': 'Atlético Huracán', 'price': 2.83},
#        {'name': 'Newells Old Boys', 'price': 3.0},
#        {'name': 'Draw', 'price': 2.75}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2023-06-23T19:00:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:48Z',
#       'outcomes': [{'name': 'Atlético Huracán', 'price': 2.83},
#        {'name': 'Newells Old Boys', 'price': 3.0},
#        {'name': 'Draw', 'price': 2.75}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2023-06-23T19:01:23Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:23Z',
#       'outcomes': [{'name': 'Atlético Huracán', 'price': 2.8},
#        {'name': 'Newells Old Boys', 'price': 2.88},
#        {'name': 'Draw', 'price': 2.7}]}]}]},
#  {'id': '7a7e0d5d24fdf52987133d715aec14af',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2023-06-23T22:40:00Z',
#   'home_team': 'Cincinnati Reds',
#   'away_team': 'Atlanta Braves',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2023-06-23T19:01:50Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:50Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.67},
#        {'name': 'Cincinnati Reds', 'price': 2.3}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2023-06-23T19:00:52Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:52Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.7},
#        {'name': 'Cincinnati Reds', 'price': 2.31}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2023-06-23T19:01:54Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:54Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.7},
#        {'name': 'Cincinnati Reds', 'price': 2.31}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2023-06-23T19:00:53Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:53Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.65},
#        {'name': 'Cincinnati Reds', 'price': 2.3}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2023-06-23T19:01:56Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:56Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.69},
#        {'name': 'Cincinnati Reds', 'price': 2.3}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2023-06-23T19:01:24Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:24Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.66},
#        {'name': 'Cincinnati Reds', 'price': 2.27}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2023-06-23T19:00:35Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:35Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.65},
#        {'name': 'Cincinnati Reds', 'price': 2.3}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2023-06-23T18:58:16Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T18:58:16Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.68},
#        {'name': 'Cincinnati Reds', 'price': 2.34}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2023-06-23T19:00:36Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:36Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.69},
#        {'name': 'Cincinnati Reds', 'price': 2.22}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2023-06-23T19:01:43Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:43Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.62},
#        {'name': 'Cincinnati Reds', 'price': 2.2}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2023-06-23T19:00:51Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:51Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.65},
#        {'name': 'Cincinnati Reds', 'price': 2.26}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2023-06-23T19:01:52Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:52Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.67},
#        {'name': 'Cincinnati Reds', 'price': 2.25}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2023-06-23T19:01:56Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:56Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.67},
#        {'name': 'Cincinnati Reds', 'price': 2.25}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2023-06-23T19:01:46Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:46Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.68},
#        {'name': 'Cincinnati Reds', 'price': 2.28}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2023-06-23T19:01:17Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:17Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.64},
#        {'name': 'Cincinnati Reds', 'price': 2.33}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2023-06-23T19:01:23Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:23Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.64},
#        {'name': 'Cincinnati Reds', 'price': 2.33}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2023-06-23T19:01:31Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:31Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.64},
#        {'name': 'Cincinnati Reds', 'price': 2.33}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2023-06-23T19:01:54Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:54Z',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 1.64},
#        {'name': 'Cincinnati Reds', 'price': 2.33}]}]}]},
#  {'id': '85dc387103ca0423e1ff99e27a11177a',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2023-06-23T22:40:00Z',
#   'home_team': 'Detroit Tigers',
#   'away_team': 'Minnesota Twins',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2023-06-23T19:01:50Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:50Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.1},
#        {'name': 'Minnesota Twins', 'price': 1.77}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2023-06-23T19:00:52Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:52Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.17},
#        {'name': 'Minnesota Twins', 'price': 1.79}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2023-06-23T19:01:54Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:54Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.17},
#        {'name': 'Minnesota Twins', 'price': 1.79}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2023-06-23T19:00:53Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:53Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.1},
#        {'name': 'Minnesota Twins', 'price': 1.77}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2023-06-23T19:01:56Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:56Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.16},
#        {'name': 'Minnesota Twins', 'price': 1.79}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2023-06-23T19:01:24Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:24Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.08},
#        {'name': 'Minnesota Twins', 'price': 1.77}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2023-06-23T19:00:35Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:35Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.1},
#        {'name': 'Minnesota Twins', 'price': 1.77}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2023-06-23T18:58:16Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T18:58:16Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.18},
#        {'name': 'Minnesota Twins', 'price': 1.77}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2023-06-23T19:00:36Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:36Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.17},
#        {'name': 'Minnesota Twins', 'price': 1.72}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2023-06-23T19:01:43Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:43Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.1},
#        {'name': 'Minnesota Twins', 'price': 1.7}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2023-06-23T19:00:51Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:51Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.08},
#        {'name': 'Minnesota Twins', 'price': 1.75}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2023-06-23T19:01:52Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:52Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.15},
#        {'name': 'Minnesota Twins', 'price': 1.71}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2023-06-23T19:01:56Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:56Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.1},
#        {'name': 'Minnesota Twins', 'price': 1.77}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2023-06-23T19:01:46Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:46Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.08},
#        {'name': 'Minnesota Twins', 'price': 1.78}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2023-06-23T19:01:23Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:23Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.14},
#        {'name': 'Minnesota Twins', 'price': 1.74}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2023-06-23T19:01:17Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:17Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.14},
#        {'name': 'Minnesota Twins', 'price': 1.74}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2023-06-23T19:01:31Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:31Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.14},
#        {'name': 'Minnesota Twins', 'price': 1.74}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2023-06-23T19:01:54Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:54Z',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 2.14},
#        {'name': 'Minnesota Twins', 'price': 1.74}]}]}]},
#  {'id': '667c8b6b010a64e10255124d82833a98',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2023-06-23T22:40:00Z',
#   'home_team': 'Tampa Bay Rays',
#   'away_team': 'Kansas City Royals',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2023-06-23T19:01:50Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:50Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.2},
#        {'name': 'Tampa Bay Rays', 'price': 1.38}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2023-06-23T19:00:52Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:52Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.2},
#        {'name': 'Tampa Bay Rays', 'price': 1.41}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2023-06-23T19:01:54Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:54Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.2},
#        {'name': 'Tampa Bay Rays', 'price': 1.41}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2023-06-23T19:00:53Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:53Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.2},
#        {'name': 'Tampa Bay Rays', 'price': 1.37}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2023-06-23T19:01:56Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:56Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.1},
#        {'name': 'Tampa Bay Rays', 'price': 1.38}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2023-06-23T19:01:24Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:24Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.2},
#        {'name': 'Tampa Bay Rays', 'price': 1.37}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2023-06-23T19:00:35Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:35Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.15},
#        {'name': 'Tampa Bay Rays', 'price': 1.37}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2023-06-23T18:58:16Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T18:58:16Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.25},
#        {'name': 'Tampa Bay Rays', 'price': 1.4}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2023-06-23T19:00:36Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:36Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.12},
#        {'name': 'Tampa Bay Rays', 'price': 1.38}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2023-06-23T19:01:43Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:43Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.3},
#        {'name': 'Tampa Bay Rays', 'price': 1.3}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2023-06-23T19:00:51Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:51Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.34},
#        {'name': 'Tampa Bay Rays', 'price': 1.33}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2023-06-23T19:01:56Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:56Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.0},
#        {'name': 'Tampa Bay Rays', 'price': 1.4}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2023-06-23T19:01:52Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:52Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.1},
#        {'name': 'Tampa Bay Rays', 'price': 1.38}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2023-06-23T19:01:46Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:46Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.2},
#        {'name': 'Tampa Bay Rays', 'price': 1.37}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2023-06-23T19:01:17Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:17Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.3},
#        {'name': 'Tampa Bay Rays', 'price': 1.36}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2023-06-23T19:01:31Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:31Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.3},
#        {'name': 'Tampa Bay Rays', 'price': 1.36}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2023-06-23T19:01:23Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:23Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.25},
#        {'name': 'Tampa Bay Rays', 'price': 1.36}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2023-06-23T19:01:54Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:54Z',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': 3.3},
#        {'name': 'Tampa Bay Rays', 'price': 1.36}]}]}]},
#  {'id': '92a36e999a4313dca355d48cfdf41e30',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2023-06-23T22:40:00Z',
#   'home_team': 'Miami Marlins',
#   'away_team': 'Pittsburgh Pirates',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2023-06-23T19:01:50Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:50Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.48},
#        {'name': 'Pittsburgh Pirates', 'price': 2.8}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2023-06-23T19:00:52Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:52Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.51},
#        {'name': 'Pittsburgh Pirates', 'price': 2.81}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2023-06-23T19:01:54Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:54Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.51},
#        {'name': 'Pittsburgh Pirates', 'price': 2.81}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2023-06-23T19:00:53Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:53Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.47},
#        {'name': 'Pittsburgh Pirates', 'price': 2.8}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2023-06-23T19:01:56Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:56Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.5},
#        {'name': 'Pittsburgh Pirates', 'price': 2.7}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2023-06-23T19:01:24Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:24Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.47},
#        {'name': 'Pittsburgh Pirates', 'price': 2.75}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2023-06-23T19:00:35Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:35Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.45},
#        {'name': 'Pittsburgh Pirates', 'price': 2.8}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2023-06-23T18:58:16Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T18:58:16Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.5},
#        {'name': 'Pittsburgh Pirates', 'price': 2.82}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2023-06-23T19:00:36Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:36Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.47},
#        {'name': 'Pittsburgh Pirates', 'price': 2.77}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2023-06-23T19:01:43Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:43Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.44},
#        {'name': 'Pittsburgh Pirates', 'price': 2.65}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2023-06-23T19:00:51Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:51Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.46},
#        {'name': 'Pittsburgh Pirates', 'price': 2.73}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2023-06-23T19:01:52Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:52Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.48},
#        {'name': 'Pittsburgh Pirates', 'price': 2.75}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2023-06-23T19:01:56Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:56Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.48},
#        {'name': 'Pittsburgh Pirates', 'price': 2.7}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2023-06-23T19:01:46Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:46Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.47},
#        {'name': 'Pittsburgh Pirates', 'price': 2.8}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2023-06-23T19:01:31Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:31Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.5},
#        {'name': 'Pittsburgh Pirates', 'price': 2.7}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2023-06-23T19:01:17Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:17Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.5},
#        {'name': 'Pittsburgh Pirates', 'price': 2.7}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2023-06-23T19:01:23Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:23Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.5},
#        {'name': 'Pittsburgh Pirates', 'price': 2.65}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2023-06-23T19:01:54Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:54Z',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 1.5},
#        {'name': 'Pittsburgh Pirates', 'price': 2.7}]}]}]},
#  {'id': 'ee18369fc18bcc978b8e7de359f6d0c2',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2023-06-23T23:05:00Z',
#   'home_team': 'Baltimore Orioles',
#   'away_team': 'Seattle Mariners',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2023-06-23T19:01:50Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:50Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.95},
#        {'name': 'Seattle Mariners', 'price': 1.87}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2023-06-23T19:00:36Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:36Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.93},
#        {'name': 'Seattle Mariners', 'price': 1.91}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2023-06-23T19:00:53Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:53Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.98},
#        {'name': 'Seattle Mariners', 'price': 1.86}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2023-06-23T19:01:56Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:56Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.99},
#        {'name': 'Seattle Mariners', 'price': 1.92}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2023-06-23T19:00:51Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:51Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.94},
#        {'name': 'Seattle Mariners', 'price': 1.88}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2023-06-23T19:01:43Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:43Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.91},
#        {'name': 'Seattle Mariners', 'price': 1.83}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2023-06-23T19:00:35Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:35Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.95},
#        {'name': 'Seattle Mariners', 'price': 1.87}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2023-06-23T19:01:52Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:52Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.91},
#        {'name': 'Seattle Mariners', 'price': 1.91}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2023-06-23T19:01:56Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:56Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.95},
#        {'name': 'Seattle Mariners', 'price': 1.87}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2023-06-23T19:01:24Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:24Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.95},
#        {'name': 'Seattle Mariners', 'price': 1.87}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2023-06-23T18:58:16Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T18:58:16Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.98},
#        {'name': 'Seattle Mariners', 'price': 1.93}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2023-06-23T19:01:46Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:46Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.93},
#        {'name': 'Seattle Mariners', 'price': 1.92}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2023-06-23T19:00:52Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:52Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 2.0},
#        {'name': 'Seattle Mariners', 'price': 1.91}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2023-06-23T19:01:54Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:54Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 2.0},
#        {'name': 'Seattle Mariners', 'price': 1.91}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2023-06-23T19:01:17Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:17Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.95},
#        {'name': 'Seattle Mariners', 'price': 1.88}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2023-06-23T19:01:54Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:54Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.95},
#        {'name': 'Seattle Mariners', 'price': 1.88}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2023-06-23T19:01:31Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:31Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.95},
#        {'name': 'Seattle Mariners', 'price': 1.88}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2023-06-23T19:01:23Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:23Z',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 1.95},
#        {'name': 'Seattle Mariners', 'price': 1.88}]}]}]},
#  {'id': 'ef17411cc57fb0334e06217d4d3e76ac',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2023-06-23T23:05:00Z',
#   'home_team': 'Philadelphia Phillies',
#   'away_team': 'New York Mets',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2023-06-23T19:01:50Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:50Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 2.0},
#        {'name': 'Philadelphia Phillies', 'price': 1.83}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2023-06-23T19:00:52Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:52Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 2.05},
#        {'name': 'Philadelphia Phillies', 'price': 1.87}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2023-06-23T19:01:54Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:54Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 2.05},
#        {'name': 'Philadelphia Phillies', 'price': 1.87}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2023-06-23T19:00:53Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:53Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 2.02},
#        {'name': 'Philadelphia Phillies', 'price': 1.83}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2023-06-23T19:01:56Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:56Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 2.05},
#        {'name': 'Philadelphia Phillies', 'price': 1.87}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2023-06-23T19:01:24Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:24Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 2.0},
#        {'name': 'Philadelphia Phillies', 'price': 1.83}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2023-06-23T19:00:35Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:35Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 2.0},
#        {'name': 'Philadelphia Phillies', 'price': 1.83}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2023-06-23T18:58:16Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T18:58:16Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 2.0},
#        {'name': 'Philadelphia Phillies', 'price': 1.91}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2023-06-23T19:00:36Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:36Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 2.06},
#        {'name': 'Philadelphia Phillies', 'price': 1.8}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2023-06-23T19:01:56Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:56Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 1.95},
#        {'name': 'Philadelphia Phillies', 'price': 1.87}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2023-06-23T19:00:51Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:00:51Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 1.96},
#        {'name': 'Philadelphia Phillies', 'price': 1.85}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2023-06-23T19:01:43Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:43Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 1.95},
#        {'name': 'Philadelphia Phillies', 'price': 1.8}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2023-06-23T19:01:52Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:52Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 2.0},
#        {'name': 'Philadelphia Phillies', 'price': 1.83}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2023-06-23T19:01:46Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:46Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 2.02},
#        {'name': 'Philadelphia Phillies', 'price': 1.85}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2023-06-23T19:01:17Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:17Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 1.95},
#        {'name': 'Philadelphia Phillies', 'price': 1.85}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2023-06-23T19:01:23Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:23Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 1.95},
#        {'name': 'Philadelphia Phillies', 'price': 1.85}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2023-06-23T19:01:31Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:31Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 1.95},
#        {'name': 'Philadelphia Phillies', 'price': 1.85}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2023-06-23T19:01:54Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2023-06-23T19:01:54Z',
#       'outcomes': [{'name': 'New York Mets', 'price': 1.95},
#        {'name': 'Philadelphia Phillies', 'price': 1.85}]}]}]}]

# %%
len(odds_response)
# Out:
# 14

# %% [markdown]
# ### Event Class
# - Each ``Event`` object represents an indivudal sporting event
# - The ``data`` parameter contains all of the odds data that is received from the API call

# %%
BOOKMAKER_INDEX = 0
NAME_INDEX = 1
ODDS_INDEX = 2
FIRST = 0

class Event:
    def __init__(self, data):
        self.data = data
        self.sport_key = data['sport_key']
        self.id = data['id']
        
    def find_best_odds(self):
        # number of possible outcomes for a sporting event
        num_outcomes = len(self.data['bookmakers'][FIRST]['markets'][FIRST]['outcomes'])
        self.num_outcomes = num_outcomes

        # finding the best odds for each outcome in each event
        best_odds = [[None, None, float('-inf')] for _ in range(num_outcomes)]
        # [Bookmaker, Name, Price]

        bookmakers = self.data['bookmakers']
        for index, bookmaker in enumerate(bookmakers):

            # determing the odds offered by each bookmaker
            for outcome in range(num_outcomes):
                # determining if any of the bookmaker odds are better than the current best odds
                bookmaker_odds = float(bookmaker['markets'][FIRST]['outcomes'][outcome]['price'])
                current_best_odds = best_odds[outcome][ODDS_INDEX]

                if bookmaker_odds > current_best_odds:
                    best_odds[outcome][BOOKMAKER_INDEX] = bookmaker['title']
                    best_odds[outcome][NAME_INDEX] = bookmaker['markets'][FIRST]['outcomes'][outcome]['name']
                    best_odds[outcome][ODDS_INDEX] = bookmaker_odds
                    
        self.best_odds = best_odds
        return best_odds
    
    def arbitrage(self):
        total_arbitrage_percentage = 0
        for odds in self.best_odds:
            total_arbitrage_percentage += (1.0 / odds[ODDS_INDEX])
            
        self.total_arbitrage_percentage = total_arbitrage_percentage
        self.expected_earnings = (BET_SIZE / total_arbitrage_percentage) - BET_SIZE
        
        # if the sum of the reciprocals of the odds is less than 1, there is opportunity for arbitrage
        if total_arbitrage_percentage < 1:
            return True
        return False
    
    # converts decimal/European best odds to American best odds
    def convert_decimal_to_american(self):
        best_odds = self.best_odds
        for odds in best_odds:
            decimal = odds[ODDS_INDEX]
            if decimal >= 2:
                american = (decimal - 1) * 100
            elif decimal < 2:
                american = -100 / (decimal - 1)
            odds[ODDS_INDEX] = round(american, 2)
        return best_odds
     
    def calculate_arbitrage_bets(self):
        bet_amounts = []
        for outcome in range(self.num_outcomes):
            individual_arbitrage_percentage = 1 / self.best_odds[outcome][ODDS_INDEX]
            bet_amount = (BET_SIZE * individual_arbitrage_percentage) / self.total_arbitrage_percentage
            bet_amounts.append(round(bet_amount, 2))
        
        self.bet_amounts = bet_amounts
        return bet_amounts

# %% [markdown]
# ### Parsing Events and Calculating Arbitrage Bets
# - `BET_SIZE` is the amount of money in USD that you would like to bet across the outcomes of an event.
# - This calculation will used unbiased arbitrage, where the profit is the same regardless of the outcome.

# %%
events = []
for data in odds_response:
    if len(data["bookmakers"]) > 0:
        events.append(Event(data))
    
arbitrage_events = []
for event in events:
    best_odds = event.find_best_odds()
    if event.arbitrage():
        arbitrage_events.append(event)
        
for event in arbitrage_events:
    event.calculate_arbitrage_bets()
    event.convert_decimal_to_american()

# %% [markdown]
# ### Creating Dataframe and Writing to Excel File

# %%
MAX_OUTCOMES = max([event.num_outcomes for event in arbitrage_events])
ARBITRAGE_EVENTS_COUNT = len(arbitrage_events)

my_columns = ['ID', 'Sport Key', 'Expected Earnings'] + list(np.array([[f'Bookmaker #{outcome}', f'Name #{outcome}', f'Odds #{outcome}', f'Amount to Buy #{outcome}'] for outcome in range(1, MAX_OUTCOMES + 1)]).flatten())
dataframe = pd.DataFrame(columns=my_columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/_p/4cdpxbv51plcbc0zl6hzbwk80000gn/T/ipykernel_32903/1577222615.py in <module>
# ----> 1 MAX_OUTCOMES = max([event.num_outcomes for event in arbitrage_events])
#       2 ARBITRAGE_EVENTS_COUNT = len(arbitrage_events)
#       3
#       4 my_columns = ['ID', 'Sport Key', 'Expected Earnings'] + list(np.array([[f'Bookmaker #{outcome}', f'Name #{outcome}', f'Odds #{outcome}', f'Amount to Buy #{outcome}'] for outcome in range(1, MAX_OUTCOMES + 1)]).flatten())
#       5 dataframe = pd.DataFrame(columns=my_columns)
#
# ValueError: max() arg is an empty sequence

# %%
dataframe
# Out:
# Empty DataFrame
# Columns: [ID, Sport Key, Expected Earnings, Bookmaker #1, Name #1, Odds #1, Amount to Buy #1, Bookmaker #2, Name #2, Odds #2, Amount to Buy #2, Bookmaker #3, Name #3, Odds #3, Amount to Buy #3]
# Index: []

# %%
for event in arbitrage_events:
    # print(event.best_odds)
    row = []
    row.append(event.id)
    row.append(event.sport_key)
    row.append(round(event.expected_earnings, 2))
    for index, outcome in enumerate(event.best_odds):
        row.append(outcome[BOOKMAKER_INDEX])
        row.append(outcome[NAME_INDEX])
        row.append(outcome[ODDS_INDEX])
        row.append(event.bet_amounts[index])
    while len(row) < len(dataframe.columns):
        row.append('N/A')
    dataframe.loc[len(dataframe.index)] = row

# %%
writer = pd.ExcelWriter('bets.xlsx')
dataframe.to_excel(writer, index=False)
writer.save()

# %% [markdown]
# ### Formatting the Excel File

# %%
BLACK = '000000'
LIGHT_GREY = 'D6D6D6'
DARK_GREY = '9F9F9F'
RED = 'FEA0A0'
BLUE = 'A0CEFE'
YELLOW = 'FFE540'

COLORS = [RED, BLUE]

ID_COLUMN_FILL = PatternFill(fill_type='solid', start_color=DARK_GREY, end_color=DARK_GREY)
SPORT_KEY_COLUMN_FILL = PatternFill(fill_type='solid', start_color=LIGHT_GREY, end_color=LIGHT_GREY)
EXPECTED_EARNINGS_COLUMN_FILL = PatternFill(fill_type='solid', start_color=YELLOW, end_color=YELLOW)

CENTER_ALIGNMENT = Alignment(horizontal='center', vertical='bottom', indent=0)

TOP_ROW_BORDER = Border(bottom=Side(border_style='thick', color=BLACK))
NORMAL_ROW_BORDER = Border(top=Side(border_style='thin', color=LIGHT_GREY), bottom=Side(border_style='thin', color=DARK_GREY))

wb = load_workbook('bets.xlsx')
ws = wb.active
ws.title = 'Upcoming'
# changing width
for col in range(1, 26):
    ws.column_dimensions[chr(col + 64)].width = 20

for cell in ws['A']:
    cell.fill = ID_COLUMN_FILL
    cell.alignment = CENTER_ALIGNMENT
    
for cell in ws['B']:
    cell.fill = SPORT_KEY_COLUMN_FILL
    cell.alignment = CENTER_ALIGNMENT
    
for cell in ws['C']:
    cell.fill = EXPECTED_EARNINGS_COLUMN_FILL
    cell.alignment = CENTER_ALIGNMENT
    cell.number_format = numbers.BUILTIN_FORMATS[7]

START_INDEX = 'D'
for index in range(MAX_OUTCOMES):
    for col in ws[START_INDEX : chr(ord(START_INDEX) + 3)]:
        for cell in col:
            color = COLORS[int(index % 2)]
            cell.fill = PatternFill(fill_type='solid', start_color=color, end_color=color)
            cell.alignment = CENTER_ALIGNMENT
            if cell.column % 4 == 3:
                cell.number_format = numbers.BUILTIN_FORMATS[7]
            
    START_INDEX = chr(ord(START_INDEX) + 4)

for cell in ws['1']:
    cell.border = TOP_ROW_BORDER

for row in range(2, ARBITRAGE_EVENTS_COUNT + 2):
    for cell in ws[str(row)]:
        cell.border = NORMAL_ROW_BORDER
    
wb.save('upcoming_events_bets.xlsx')
